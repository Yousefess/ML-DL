# %% [markdown]
# # **Imports**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from torchmetrics import Accuracy, HingeLoss

# %% [markdown]
# # **Load Dataset**

# %%
# !unzip ./data/mobile_price.zip -d ./data/
# Out:
# Archive:  ./data/mobile_price.zip
#   inflating: ./data/test.csv
#   inflating: ./data/train.csv

# %%
mobile_price_dataset = pd.read_csv("./data/train.csv")

# %%
X = mobile_price_dataset.drop('price_range', axis=1).values
y = mobile_price_dataset['price_range'].values

# %% [markdown]
# # **Split**

# %%
x_train, x_valid, y_train, y_valid = train_test_split(X, y, train_size=0.7, random_state=42)

# %% [markdown]
# # **Preprocess**

# %% [markdown]
# ## Convert to tensor

# %%
x_train = torch.FloatTensor(x_train)
y_train = torch.LongTensor(y_train)

x_valid = torch.FloatTensor(x_valid)
y_valid = torch.LongTensor(y_valid)

# %% [markdown]
# ## Standardization

# %%
mu = torch.mean(x_train, dim=0) #[n_sample, n_fea]
std = torch.std(x_train, dim=0)

x_train = (x_train - mu)/std
x_valid = (x_valid - mu)/std

# %% [markdown]
# # **Dataloader**

# %% [markdown]
# ## Train

# %%
train_dataset = TensorDataset(x_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

# %% [markdown]
# ## Validation

# %%
valid_dataset = TensorDataset(x_valid, y_valid)
valid_loader = DataLoader(valid_dataset, batch_size=64)

# %% [markdown]
# # **Model**

# %%
num_features = 20
num_classes = 4

h1 = 64
h2 = 32

model = nn.Sequential(nn.Linear(num_features, h1),
                      nn.ReLU(),
                      nn.Linear(h1, h2),
                      nn.ReLU(),
                      nn.Linear(h2, num_classes),
                      )

model
# Out:
# Sequential(
#   (0): Linear(in_features=20, out_features=64, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=32, out_features=4, bias=True)
# )

# %% [markdown]
# # **Loss & Optimizer**

# %%
# loss_fn = nn.CrossEntropyLoss()
# loss_fn = HingeLoss(task='multiclass', num_classes=num_classes)

# %%
def loss_fn(outputs, targets, alpha=0.25, gamma=2):
    prob = F.softmax(outputs, dim=1)
    outputs = (1 - prob) ** gamma * torch.log(prob)
    return F.nll_loss(outputs, targets, weight=torch.ones(outputs.shape[1]) * alpha)

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# # **Device**

# %%
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
device = 'cpu'
model = model.to(device)

# %% [markdown]
# # **Utils**

# %%
class AverageMeter(object):
  """Computes and stores the average and current value"""
  def __init__(self):
    self.reset()

  def reset(self):
    self.val = 0
    self.avg = 0
    self.sum = 0
    self.count = 0

  def update(self, val, n=1):
    self.val = val
    self.sum += val * n
    self.count += n
    self.avg = self.sum / self.count

# %% [markdown]
# # **Train Loooop**

# %%
loss_train_hist = []
loss_valid_hist = []

acc_train_hist = []
acc_valid_hist = []

num_epochs = 300

for epoch in range(num_epochs):
  # Train
  model.train()
  loss_train = AverageMeter()
  acc_train = Accuracy(task='multiclass', num_classes=num_classes).to(device)
  for i, (inputs, targets) in enumerate(train_loader):
    inputs = inputs.to(device)
    targets = targets.to(device)

    outputs = model(inputs)
    loss = loss_fn(outputs, targets)

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    loss_train.update(loss.item())
    acc_train(outputs, targets)

  loss_train_hist.append(loss_train.avg)
  acc_train_hist.append(acc_train.compute().cpu())

  # Validation
  model.eval()
  loss_valid = AverageMeter()
  acc_valid = Accuracy(task='multiclass', num_classes=num_classes).to(device)
  with torch.no_grad():
    for i, (inputs, targets) in enumerate(valid_loader):
      inputs = inputs.to(device)
      targets = targets.to(device)

      outputs = model(inputs)

      loss = loss_fn(outputs, targets)

      loss_valid.update(loss.item())
      acc_valid(outputs, targets)

    loss_valid_hist.append(loss_valid.avg)
    acc_valid_hist.append(acc_valid.compute().cpu())

  if epoch % 10 == 0:
    print(f'Epoch {epoch}')
    print(f'Train: Loss = {loss_train.avg:.4}, Accuracy = {acc_train.compute():.4}')
    print(f'Valid: Loss = {loss_valid.avg:.4}, Accuracy = {acc_valid.compute():.4}')
    print()
# Out:
# Epoch 0
# Train: Loss = 0.7905, Accuracy = 0.2386
# Valid: Loss = 0.7854, Accuracy = 0.2567
#
# Epoch 10
# Train: Loss = 0.7409, Accuracy = 0.3864
# Valid: Loss = 0.7413, Accuracy = 0.395
#
# Epoch 20
# Train: Loss = 0.6539, Accuracy = 0.5343
# Valid: Loss = 0.6565, Accuracy = 0.555
#
# Epoch 30
# Train: Loss = 0.5027, Accuracy = 0.6579
# Valid: Loss = 0.5052, Accuracy = 0.6583
#
# Epoch 40
# Train: Loss = 0.348, Accuracy = 0.795
# Valid: Loss = 0.3522, Accuracy = 0.7933
#
# Epoch 50
# Train: Loss = 0.2432, Accuracy = 0.8779
# Valid: Loss = 0.2494, Accuracy = 0.8417
#
# Epoch 60
# Train: Loss = 0.1797, Accuracy = 0.9029
# Valid: Loss = 0.1868, Accuracy = 0.8667
#
# Epoch 70
# Train: Loss = 0.1398, Accuracy = 0.9164
# Valid: Loss = 0.1474, Accuracy = 0.8833
#
# Epoch 80
# Train: Loss = 0.1135, Accuracy = 0.925
# Valid: Loss = 0.1214, Accuracy = 0.8933
#
# Epoch 90
# Train: Loss = 0.09508, Accuracy = 0.9314
# Valid: Loss = 0.1032, Accuracy = 0.9
#
# Epoch 100
# Train: Loss = 0.08184, Accuracy = 0.9386
# Valid: Loss = 0.09, Accuracy = 0.9133
#
# Epoch 110
# Train: Loss = 0.07181, Accuracy = 0.9421
# Valid: Loss = 0.08035, Accuracy = 0.92
#
# Epoch 120
# Train: Loss = 0.06409, Accuracy = 0.9479
# Valid: Loss = 0.07274, Accuracy = 0.9267
#
# Epoch 130
# Train: Loss = 0.05786, Accuracy = 0.9507
# Valid: Loss = 0.06698, Accuracy = 0.925
#
# Epoch 140
# Train: Loss = 0.05285, Accuracy = 0.9557
# Valid: Loss = 0.06228, Accuracy = 0.9283
#
# Epoch 150
# Train: Loss = 0.04876, Accuracy = 0.9579
# Valid: Loss = 0.05859, Accuracy = 0.9283
#
# Epoch 160
# Train: Loss = 0.04516, Accuracy = 0.9607
# Valid: Loss = 0.05548, Accuracy = 0.9283
#
# Epoch 170
# Train: Loss = 0.0422, Accuracy = 0.9643
# Valid: Loss = 0.05299, Accuracy = 0.93
#
# Epoch 180
# Train: Loss = 0.03966, Accuracy = 0.9664
# Valid: Loss = 0.05091, Accuracy = 0.93
#
# Epoch 190
# Train: Loss = 0.03745, Accuracy = 0.9671
# Valid: Loss = 0.04931, Accuracy = 0.9283
#
# Epoch 200
# Train: Loss = 0.0354, Accuracy = 0.9686
# Valid: Loss = 0.04782, Accuracy = 0.93
#
# Epoch 210
# Train: Loss = 0.03362, Accuracy = 0.97
# Valid: Loss = 0.04642, Accuracy = 0.93
#
# Epoch 220
# Train: Loss = 0.03209, Accuracy = 0.9729
# Valid: Loss = 0.04539, Accuracy = 0.9317
#
# Epoch 230
# Train: Loss = 0.03061, Accuracy = 0.9743
# Valid: Loss = 0.04444, Accuracy = 0.9317
#
# Epoch 240
# Train: Loss = 0.02942, Accuracy = 0.9793
# Valid: Loss = 0.04363, Accuracy = 0.9333
#
# Epoch 250
# Train: Loss = 0.02814, Accuracy = 0.9793
# Valid: Loss = 0.04299, Accuracy = 0.935
#
# Epoch 260
# Train: Loss = 0.02708, Accuracy = 0.98
# Valid: Loss = 0.04238, Accuracy = 0.935
#
# Epoch 270
# Train: Loss = 0.02603, Accuracy = 0.9821
# Valid: Loss = 0.04185, Accuracy = 0.935
#
# Epoch 280
# Train: Loss = 0.02498, Accuracy = 0.9821
# Valid: Loss = 0.04135, Accuracy = 0.935
#
# Epoch 290
# Train: Loss = 0.02408, Accuracy = 0.9821
# Valid: Loss = 0.0409, Accuracy = 0.9333

# %% [markdown]
# # **Plot**

# %%
plt.figure(figsize=(8, 6))

plt.plot(range(num_epochs), loss_train_hist, 'r-', label='Train')
plt.plot(range(num_epochs), loss_valid_hist, 'b-', label='Validation')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# %%
plt.figure(figsize=(8, 6))

plt.plot(range(num_epochs), acc_train_hist, 'r-', label='Train')
plt.plot(range(num_epochs), acc_valid_hist, 'b-', label='Validation')

plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.grid(True)
plt.legend()
