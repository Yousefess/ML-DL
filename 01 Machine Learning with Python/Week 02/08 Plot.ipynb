# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# %%
plt.plot(x, y, 'r--P', label='y=2x')
plt.legend()
plt.title('test')
plt.xlabel('x')
plt.ylabel('y');

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]

# %%
plt.plot(x1, y1, 'b:D', label='y=x^2')
plt.legend();

# %%
plt.plot(x, y, 'r--P', label='y=2x')
plt.plot(x1, y1, 'b:D', label='y=x^2');

# %%
plt.subplot(211)
plt.plot(x, y, 'r--P', label='y=2x')
plt.legend()

plt.subplot(212)
plt.plot(x1, y1, 'b:D', label='y=x^2')
plt.legend()

plt.savefig('./out/plot.png')

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#            a         b         c         d
# 0   0.779902  0.259132  0.685673  0.776475
# 1   0.122081  0.672941  0.739791  0.158870
# 2   0.652165  0.324526  0.879123  0.004031
# 3   0.631020  0.111425  0.344028  0.583048
# 4   0.622741  0.980199  0.328087  0.616287
# 5   0.001655  0.515775  0.648272  0.597546
# 6   0.822606  0.694277  0.039309  0.995338
# 7   0.768925  0.604629  0.897116  0.181405
# 8   0.192153  0.830656  0.171109  0.227820
# 9   0.103233  0.432155  0.381862  0.623374
# 10  0.005188  0.805563  0.794204  0.825958
# 11  0.068416  0.484011  0.067547  0.902736
# 12  0.019896  0.776023  0.399518  0.784511
# 13  0.517969  0.203669  0.274557  0.496825
# 14  0.613496  0.975270  0.873572  0.530866
# 15  0.659592  0.967751  0.287820  0.054557
# 16  0.454364  0.032423  0.420852  0.731357
# 17  0.914562  0.773502  0.053839  0.323577
# 18  0.128929  0.778079  0.137639  0.060665
# 19  0.371077  0.490970  0.625642  0.407031
# 20  0.520173  0.534261  0.125325  0.487474
# 21  0.855185  0.118001  0.301827  0.534776
# 22  0.849872  0.953981  0.133739  0.577795
# 23  0.788223  0.328690  0.925380  0.623984
# 24  0.312239  0.827534  0.810426  0.282255
# 25  0.421418  0.725619  0.305724  0.176478
# 26  0.624794  0.555746  0.901154  0.852085
# 27  0.539520  0.295532  0.474018  0.840354
# 28  0.515510  0.802992  0.683845  0.804678
# 29  0.290723  0.203138  0.464711  0.145486
# 30  0.342215  0.401153  0.947507  0.586652
# 31  0.587260  0.608225  0.503327  0.714682
# 32  0.813590  0.957458  0.167503  0.812099
# 33  0.389261  0.125872  0.786456  0.383807
# 34  0.406052  0.118272  0.504549  0.289313
# 35  0.951211  0.087875  0.723954  0.165451
# 36  0.375769  0.691178  0.652296  0.476535
# 37  0.626601  0.686418  0.357456  0.004885
# 38  0.599634  0.060197  0.316526  0.788739
# 39  0.173260  0.813077  0.722614  0.714391
# 40  0.603346  0.483482  0.899748  0.624550
# 41  0.389911  0.165048  0.288443  0.504309
# 42  0.433400  0.932384  0.166707  0.948606
# 43  0.232065  0.376448  0.257813  0.282811
# 44  0.229298  0.908570  0.769687  0.308716
# 45  0.434371  0.131757  0.689743  0.800962
# 46  0.483095  0.347349  0.122279  0.015718
# 47  0.363354  0.730759  0.611368  0.645447
# 48  0.173057  0.482471  0.985377  0.376448
# 49  0.561092  0.092497  0.953574  0.491156

# %%
k = df.plot.scatter(x='a', y='b', color='red', label='Group 1')
df.plot.scatter(x='c', y='d', color='blue', label='Group 2', ax=k);

# %% [markdown]
# ### Example 2

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.496932  0.851738  0.006393  0.324392
# 1  0.786915  0.692679  0.745611  0.521203
# 2  0.798361  0.923446  0.754470  0.296235
# 3  0.059050  0.293500  0.375056  0.769901
# 4  0.350153  0.063320  0.576316  0.025481
# 5  0.534640  0.703223  0.918207  0.103007
# 6  0.260815  0.814732  0.012409  0.383332
# 7  0.758855  0.800887  0.690458  0.089478
# 8  0.995975  0.972143  0.830861  0.175793
# 9  0.719373  0.557337  0.713074  0.008151

# %%
df.plot.bar();

# %%
df.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df.plot.barh(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Example 3

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df
# Out:
#           A         B         C         D         E
# 0  0.534908  0.486740  0.241030  0.487432  0.837110
# 1  0.038985  0.328065  0.395625  0.153313  0.487593
# 2  0.694582  0.071261  0.804408  0.365732  0.681076
# 3  0.218119  0.735603  0.830816  0.034438  0.861768
# 4  0.650210  0.811359  0.400795  0.387766  0.044111
# 5  0.221074  0.433043  0.108832  0.252890  0.938808
# 6  0.903642  0.591760  0.272724  0.932678  0.582329
# 7  0.590128  0.734576  0.684475  0.483706  0.163759
# 8  0.303758  0.707076  0.647739  0.315415  0.862460
# 9  0.235785  0.827443  0.229932  0.169759  0.366881

# %%
df.plot.box();

# %%
df.plot.box(color={'boxes': 'Green', 'whiskers': 'red', 'medians': 'Blue', 'caps': 'Gray'});

# %%
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8])
# Out:
# <Axes: >

# %% [markdown]
# ### Example 4

# %%
df = pd.DataFrame(np.random.rand(10, 5))
df.boxplot()
# Out:
# <Axes: >

# %%
plt.style.use('ggplot')
df = pd.DataFrame(np.random.rand(50, 3), columns=['a', 'b', 'c'])
df
# Out:
#            a         b         c
# 0   0.193554  0.675893  0.159226
# 1   0.298952  0.405898  0.561193
# 2   0.106634  0.189495  0.210509
# 3   0.365827  0.023562  0.520009
# 4   0.075960  0.522862  0.439434
# 5   0.052862  0.410239  0.070826
# 6   0.159911  0.827848  0.936035
# 7   0.651246  0.801725  0.722430
# 8   0.348161  0.215943  0.986972
# 9   0.672356  0.431288  0.186373
# 10  0.046063  0.582339  0.621637
# 11  0.442515  0.245504  0.785987
# 12  0.557364  0.493042  0.094694
# 13  0.021678  0.853001  0.363600
# 14  0.148016  0.308753  0.513517
# 15  0.020067  0.030937  0.398215
# 16  0.456243  0.845502  0.206147
# 17  0.358189  0.279624  0.911914
# 18  0.410800  0.259234  0.246498
# 19  0.560151  0.477142  0.038396
# 20  0.833852  0.697157  0.799022
# 21  0.221614  0.267096  0.065049
# 22  0.774215  0.552913  0.732725
# 23  0.796636  0.772680  0.247563
# 24  0.390716  0.602720  0.173090
# 25  0.855912  0.565374  0.741813
# 26  0.211653  0.900354  0.755129
# 27  0.350393  0.923679  0.703716
# 28  0.044141  0.452278  0.937860
# 29  0.965121  0.930500  0.269479
# 30  0.181759  0.490858  0.641330
# 31  0.503777  0.968826  0.047692
# 32  0.376918  0.738788  0.518933
# 33  0.962419  0.623809  0.987534
# 34  0.541507  0.489987  0.362793
# 35  0.345076  0.537555  0.891147
# 36  0.086747  0.438375  0.914217
# 37  0.003522  0.009436  0.115251
# 38  0.359203  0.512912  0.686064
# 39  0.106107  0.057185  0.773281
# 40  0.189201  0.399309  0.503169
# 41  0.100446  0.754784  0.814438
# 42  0.299493  0.699805  0.560118
# 43  0.700085  0.743624  0.270570
# 44  0.704099  0.791318  0.023540
# 45  0.585207  0.519775  0.717591
# 46  0.600536  0.617723  0.294711
# 47  0.589027  0.271743  0.331512
# 48  0.273936  0.662538  0.529559
# 49  0.249943  0.399709  0.421919

# %%
df.plot(kind='scatter', x='a', y='b', s=df['c']*200, color='green')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# ### Example 5

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=['A', 'B', 'C'])
df
# Out:
#           A         B         C
# 0  0.825452  0.616210  0.533734
# 1  0.410884  0.026917  0.771950
# 2  0.416043  0.258928  0.555852
# 3  0.287275  0.287165  0.107178
# 4  0.039720  0.102026  0.784257
# 5  0.353737  0.677227  0.421997
# 6  0.253699  0.308465  0.040938
# 7  0.047807  0.400480  0.302827
# 8  0.949477  0.796016  0.258722
# 9  0.030104  0.603170  0.717904

# %%
df.plot(kind='area');

# %% [markdown]
# ### Example 6

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

# %% [markdown]
# ### Example 7

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)

left, width = 0.1, 0.65
bottom = 0.1
width = 0.65
height = 0.65
bottom_h = left+width+0.02
left_h = left+width+0.02

rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom_h, width, 0.2]
rect_histy = [left_h, bottom, 0.2, height]
plt.figure(1, figsize=(8, 8))
axScatter = plt.axes(rect_scatter)
axHistx = plt.axes(rect_histx)
axHisty = plt.axes(rect_histy)

plt.figure(1, figsize=(8, 8))
axScatter = plt.axes(rect_scatter)
axHistx = plt.axes(rect_histx)
axHisty = plt.axes(rect_histy)

axScatter.scatter(x, y, c='r')

binwidth = 0.25
xymax = np.max([np.max(np.fabs(x)), np.max(np.fabs(y))])
lim = (int(xymax/binwidth) + 1) * binwidth
axScatter.set_xlim((-lim, lim))
axScatter.set_ylim((-lim, lim))
bins = np.arange(-lim, lim + binwidth, binwidth)

axHistx.hist(x, bins=bins, color='green')

axHisty.hist(y, bins=bins, orientation='horizontal', color='b')

axHistx.set_xlim(axScatter.get_xlim())
axHisty.set_ylim(axScatter.get_ylim() );
